# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
nursery_data = pd.read_csv('datasets/nursery.csv', index_col='Id')
nursery_data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>parents</th>
#       <th>has_nurs</th>
#       <th>form</th>
#       <th>children</th>
#       <th>housing</th>
#       <th>finance</th>
#       <th>social</th>
#       <th>health</th>
#     </tr>
#     <tr>
#       <th>Id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>usual</td>
#       <td>proper</td>
#       <td>complete</td>
#       <td>1</td>
#       <td>convenient</td>
#       <td>convenient</td>
#       <td>nonprob</td>
# ...

# %%
# vertical subset attack results
v_subset_nursery = mpimg.imread('robustness_analysis/categorical_neighbourhood/plots/nursery/vertical_subset_n.png')
plt.imshow(v_subset_nursery)

# %% [markdown]
# We choose gamma=30; 6 columns released -> attack success cca. 70% and show the utility.
# We record the utility for all combinations of 6 out 8 attributes released (28 combinations)
