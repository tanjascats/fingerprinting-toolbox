# %% [markdown]
# # Fingerprinting Categorical Data
# ## Nearest Neighbours Approach

# %% [markdown]
# In this notebook we analyse the behaviour of the fingerprinting technique for categorical data. The approach examines the neighbourhood of the observed item to decide how to mark it. The technique works for numerical type of data as well - in this setting the AK scheme is used. In the settings where the dataset contains a mix of data types, the techniques are chosen dynamically, based on the value chosen for marking.

# %%
# This is important for module import 
import sys, os
if 'C:/Users/tsarcevic/PycharmProjects/fingerprinting-toolbox/' not in sys.path:
    sys.path.append('C:/Users/tsarcevic/PycharmProjects/fingerprinting-toolbox/')
os.chdir('../')

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from schemes.categorical_neighbourhood.categorical_neighbourhood import CategoricalNeighbourhood
from utils import *

# %% [markdown]
# Let us take a look at our data.

# %%
dataset_name = "german_credit_sample"
dataset, primary_key = import_dataset(dataset_name)
dataset
# Out:
# Dataset: datasets/german_credit_sample.csv
#     Id checking_account  duration credit_hist purpose  credit_amount savings  \
# 0    0              A11         6         A34     A43           1169     A65
# 1    1              A12        48         A32     A43           5951     A61
# 2    2              A14        12         A34     A46           2096     A61
# 3    3              A11        42         A32     A42           7882     A61
# 4    4              A11        24         A33     A40           4870     A61
# 5    5              A14        36         A32     A46           9055     A65
# 6    6              A14        24         A32     A42           2835     A63
# 7    7              A12        36         A32     A41           6948     A61
# 8    8              A14        12         A32     A43           3059     A64
# 9    9              A12        30         A34     A40           5234     A61
# 10  10              A12        12         A32     A40           1295     A61
# 11  11              A11        48         A32     A49           4308     A61
# 12  12              A12        12         A32     A43           1567     A61
# 13  13              A11        24         A34     A40           1199     A61
# 14  14              A11        15         A32     A40           1403     A61
# 15  15              A11        24         A32     A43           1282     A62
# 16  16              A14        24         A34     A43           2424     A65
# 17  17              A11        30         A30     A49           8072     A65
# 18  18              A12        24         A32     A41          12579     A61
# 19  19              A14        24         A32     A43           3430     A63
# 20  20              A14         9         A34     A40           2134     A61
# 21  21              A11         6         A32     A43           2647     A63
# 22  22              A11        10         A34     A40           2241     A61
# 23  23              A12        12         A34     A41           1804     A62
# 24  24              A14        10         A34     A42           2069     A65
# 25  25              A11         6         A32     A42           1374     A61
# 26  26              A14         6         A30     A43            426     A61
# 27  27              A13        12         A31     A43            409     A64
# 28  28              A12         7         A32     A43           2415     A61
# 29  29              A11        60         A33     A49           6836     A61
#
#    employment_since  installment_rate sex_status debtors  residence_since
# 0               A75                 4        A93    A101                4
# 1               A73                 2        A92    A101                2
# 2               A74                 2        A93    A101                3
# 3               A74                 2        A93    A103                4
# 4               A73                 3        A93    A101                4
# 5               A73                 2        A93    A101                4
# 6               A75                 3        A93    A101                4
# 7               A73                 2        A93    A101                2
# 8               A74                 2        A91    A101                4
# 9               A71                 4        A94    A101                2
# 10              A72                 3        A92    A101                1
# 11              A72                 3        A92    A101                4
# 12              A73                 1        A92    A101                1
# 13              A75                 4        A93    A101                4
# 14              A73                 2        A92    A101                4
# 15              A73                 4        A92    A101                2
# 16              A75                 4        A93    A101                4
# 17              A72                 2        A93    A101                3
# 18              A75                 4        A92    A101                2
# 19              A75                 3        A93    A101                2
# 20              A73                 4        A93    A101                4
# 21              A73                 2        A93    A101                3
# 22              A72                 1        A93    A101                3
# 23              A72                 3        A93    A101                4
# 24              A73                 2        A94    A101                1
# 25              A73                 1        A93    A101                2
# 26              A75                 4        A94    A101                4
# 27              A73                 3        A92    A101                3
# 28              A73                 3        A93    A103                2
# 29              A75                 3        A93    A101                4

# %% [markdown]
# We embedd the fingerprint into our dataset. The fingerprint will be 32 bits long, and it is embedded in every third rown in the dataset on average. The secret key is known only to the owner of the dataset and without it is impossible to recreate the algoritm.

# %%
scheme = CategoricalNeighbourhood(gamma=3, xi=2, fingerprint_bit_length=32, number_of_buyers=10, secret_key=333, k=5)
scheme.insertion(dataset_name=dataset_name, buyer_id=0)
# Out:
# Start the insertion algorithm of a scheme for fingerprinting categorical data (neighbourhood) ...
# 	gamma: 3
# 	xi: 2
# Dataset: datasets/german_credit_sample.csv
#
# Generated fingerprint for buyer 0: 01001110011110110000100110110000
# Inserting the fingerprint...
#
# Training balltrees in: 0.02 sec.
# Size of a neighbourhood: 10 instead of 5
# 	Neighbours: [13, 14, 29, 22, 10, 3, 9, 11, 25, 20]
# Size of a neighbourhood: 8 instead of 5
# 	Neighbours: [0, 24, 2, 8, 26, 20, 5, 19]
# Size of a neighbourhood: 12 instead of 5
# 	Neighbours: [29, 11, 0, 3, 13, 14, 15, 4, 21, 25, 26, 22]
# Fingerprint inserted.
# 	fingerprinted dataset written to: schemes/categorical_neighbourhood/fingerprinted_datasets/german_credit_sample_3_2_0.csv
# Time: 0 sec.
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# True

# %% [markdown]
# The fingerprint is inserted in the dataset. We can now extract the differences to see the effect of the fingerprint.
# The rows with differences are extracted from original and fingerprinted dataset, and put one after another so that we can observe the differences (marks) more easily.
#
# It is important to note that the fingerprint marks are not only the marks where the value changes, but also the "invisible" ones where the algorithm chose not to change a value at specific locations - this is important for the extraction.

# %%
fingerprinted_data, primary_key = import_fingerprinted_dataset("categorical_neighbourhood", dataset_name, [3, 2], 0)
diff = dataset[~dataset.isin(fingerprinted_data)].dropna(how="all").index

combo = pd.concat([dataset.loc[diff], fingerprinted_data.loc[diff]])
combo = combo.sort_index()
combo
# Out:
# Dataset: schemes/categorical_neighbourhood/fingerprinted_datasets/german_credit_sample_3_2_0.csv
#     Id checking_account  duration credit_hist purpose  credit_amount savings  \
# 2    2              A14        12         A34     A46           2096     A61
# 2    2              A14        13         A34     A46           2096     A61
# 4    4              A11        24         A33     A40           4870     A61
# 4    4              A11        24         A33     A40           4870     A61
# 16  16              A14        24         A34     A43           2424     A65
# 16  16              A14        24         A34     A43           2424     A65
# 17  17              A11        30         A30     A49           8072     A65
# 17  17              A11        30         A30     A49           8072     A61
# 24  24              A14        10         A34     A42           2069     A65
# 24  24              A14        10         A34     A42           2069     A65
#
#    employment_since  installment_rate sex_status debtors  residence_since
# 2               A74                 2        A93    A101                3
# 2               A74                 2        A93    A101                3
# 4               A73                 3        A93    A101                4
# 4               A73                 3        A93    A103                4
# 16              A75                 4        A93    A101                4
# 16              A75                 4        A94    A101                4
# 17              A72                 2        A93    A101                3
# 17              A72                 2        A93    A101                3
# 24              A73                 2        A94    A101                1
# 24              A73                 0        A94    A101                1

# %% [markdown]
# There are 5 differences in total - 2 between numerical values, 3 between categorical. Let us take for example the row with id=4 and examine how the mark value was chosen (A101->A103) in attribute "debtors". For now our algorithm works such that for neighbourhood search it considers all but last three columns. The insertion algorithm looks at the values of row id=4 and searches for 5 neighbours. In this case many of them have the same distance, so k is increased, in this case to 10. The algorithm does it's magic of calcualting the neighbourhood; we obtain the neighbourhood: rows 13, 14, 29, 22, 10, 3, 9, 11, 25, 20. Next thing the algorithm does is count the frequencies of our target values in the neihgbourhood. Here we plot the frequencies:

# %%
fig, ax = plt.subplots(1,2, figsize=(8,3))
counts = dataset["debtors"][[13,14,29,22,10,3,9,11,25,20]].value_counts()
sns.barplot(counts.index, counts.values, alpha=.5, palette="Set1", ax=ax[0])

counts = counts.drop("A101")
sns.barplot(counts.index, counts.values, alpha=.95, palette="Set1", ax=ax[1])

# %% [markdown]
# The first plot represents the taget values "deptors" in the neighbourhood. We see that value A101 occurs 9 times and the value A103 1 time. Since the value A101 is the original value, we force the change as a mark and obtain only value A103 (the plot on the right). This value is chosen as a mark since it's the only remaining value.
#
# Let us see other marked categorical values. The next one is in the row with id=16 and the change occurs for attribute sex_status from value A93 to A94. The process of marking here was the same as in the previous example. The neighbourhood is calculated and frequencies of the target value obtained:

# %%
fig, ax = plt.subplots(1,2, figsize=(8,3))
counts = dataset["sex_status"][[0, 24, 2, 8, 26, 20, 5, 19]].value_counts()
sns.barplot(counts.index, counts.values, alpha=.5, palette="Set2", ax=ax[0])

counts = counts.drop("A93")
sns.barplot(counts.index, counts.values, alpha=.95, palette="Set2", ax=ax[1])

# %% [markdown]
# The plot on the left shows the frequencies of values of attribute "sex_status" in the neighbourhood: A93 occurs 5 times, A94 2 times and A91 one time (neighbourhood size is increased again; now it's 8). Since the original value is A93, we want to remove it from consideration so we obtain the plot on the right. There are two values to choose from. The algorithm weights it's random choice of mark by it's frequency, therefore A94 has more chance to be chosen as a mark than A91 - indeed it is chosen in this algorithm run.
#
# The remaining example of marking categorical value follows the same steps as shown above. We have a mark in a row 17, attribute savings (A65 -> A61). We obtain the frequencis from the neighbourhood:

# %%
fig, ax = plt.subplots(1,2, figsize=(8,3))
counts = dataset["savings"][[29, 11, 0, 3, 13, 14, 15, 4, 21, 25, 26, 22]].value_counts()
sns.barplot(counts.index,  counts.values, alpha=.5, palette="Set3", ax=ax[0])

counts = counts.drop("A65")
sns.barplot(counts.index,  counts.values, alpha=.95, palette="Set3", ax=ax[1])

# %% [markdown]
# Again, the left plot shows all the values appearing in the neighbourhood for attribute savings: A61 9 time, all others, A63, A62 and A65 1 time. We remove the original value, A65 and choose from three remaining values (plot on the right). The value A61 has way more chances to be chosen than the remaining two and the algorithm indeed chooses it as a mark.

# %% [markdown]
# The nature of choosing the most frequent values in the neighbourhood leads us to the assumption that by marking categorical values, the distribution might converge to most frequent values in the dataset. However, looking from the other perspective, the most frequent values are also most likely to be chosen for marking, and therefore forced to change to another, less frequent value (remember that the change of a values is always forced if possible).
#
#
# We can see how the distribution of values in categorical attributes changes by applying fingerprinting on the data. For this purpose we fingerprint the entire german credit dataset.

# %%
scheme = CategoricalNeighbourhood(gamma=1, xi=2, fingerprint_bit_length=32, number_of_buyers=10, secret_key=333, k=10)
scheme.insertion(dataset_name="german_credit", buyer_id=0)
# Out:
# Start the insertion algorithm of a scheme for fingerprinting categorical data (neighbourhood) ...
# 	gamma: 1
# 	xi: 2
# Dataset: datasets/german_credit.csv
#
# Generated fingerprint for buyer 0: 01001110011110110000100110110000
# Inserting the fingerprint...
#
# Training balltrees in: 0.04 sec.
# Size of a neighbourhood: 51 instead of 10
# 	Neighbours: [245, 943, 430, 527, 234, 932, 654, 469, 738, 749, 734, 204, 366, 776, 880, 614, 298, 544, 662, 411, 264, 281, 423, 206, 608, 256, 275, 694, 637, 984, 325, 273, 995, 497, 90, 769, 246, 848, 510, 241, 228, 422, 904, 89, 530, 318, 629, 941, 365, 606, 202]
# Size of a neighbourhood: 47 instead of 10
# 	Neighbours: [316, 227, 322, 650, 814, 460, 840, 587, 988, 853, 392, 457, 501, 927, 454, 805, 341, 878, 359, 899, 368, 522, 380, 396, 655, 874, 510, 260, 143, 434, 148, 286, 432, 364, 229, 338, 993, 998, 919, 552, 624, 930, 696, 777, 239, 944, 848]
# Size of a neighbourhood: 12 instead of 10
# 	Neighbours: [655, 878, 522, 853, 814, 545, 599, 929, 262, 998, 624, 541]
# Size of a neighbourhood: 14 instead of 10
# 	Neighbours: [320, 950, 474, 128, 779, 883, 394, 825, 444, 893, 195, 578, 999, 187]
# Size of a neighbourhood: 20 instead of 10
# 	Neighbours: [634, 831, 937, 504, 746, 751, 623, 291, 809, 367, 14, 736, 593, 596, 295, 531, 952, 446, 931, 462]
# Size of a neighbourhood: 18 instead of 10
# 	Neighbours: [479, 368, 812, 823, 825, 91, 589, 838, 890, 179, 426, 772, 888, 891, 371, 759, 177, 676]
# Size of a neighbourhood: 30 instead of 10
# 	Neighbours: [596, 727, 746, 155, 831, 623, 367, 722, 724, 472, 858, 958, 504, 736, 593, 649, 341, 585, 531, 775, 10, 219, 751, 569, 528, 139, 630, 934, 337, 446]
# Size of a neighbourhood: 32 instead of 10
# 	Neighbours: [115, 716, 807, 16, 803, 283, 246, 426, 490, 891, 90, 769, 159, 715, 0, 160, 266, 149, 787, 269, 879, 135, 742, 71, 894, 567, 210, 928, 519, 356, 933, 625]
# Size of a neighbourhood: 19 instead of 10
# 	Neighbours: [615, 402, 925, 720, 282, 534, 467, 63, 835, 216, 388, 827, 843, 50, 674, 645, 745, 294, 564]
# Size of a neighbourhood: 55 instead of 10
# 	Neighbours: [318, 48, 403, 776, 888, 546, 698, 932, 606, 756, 941, 621, 324, 958, 366, 411, 971, 854, 264, 978, 13, 676, 224, 125, 654, 544, 440, 772, 204, 394, 943, 45, 969, 738, 893, 379, 673, 484, 450, 52, 486, 276, 185, 219, 256, 371, 385, 196, 426, 891, 225, 357, 974, 345, 472]
# Size of a neighbourhood: 39 instead of 10
# 	Neighbours: [731, 905, 137, 649, 775, 456, 260, 586, 494, 617, 434, 998, 120, 126, 528, 624, 142, 660, 678, 84, 709, 122, 218, 762, 275, 342, 723, 488, 695, 114, 848, 39, 713, 279, 353, 217, 521, 413, 903]
# Size of a neighbourhood: 13 instead of 10
# 	Neighbours: [233, 288, 28, 447, 976, 173, 498, 732, 1, 600, 696, 709, 39]
# Size of a neighbourhood: 20 instead of 10
# 	Neighbours: [592, 810, 140, 60, 401, 400, 407, 612, 819, 806, 220, 913, 290, 109, 855, 67, 847, 622, 674, 167]
# Size of a neighbourhood: 10 instead of 10
# 	Neighbours: [789, 621, 857, 304, 852, 133, 263, 68, 800, 318]
# Size of a neighbourhood: 14 instead of 10
# 	Neighbours: [217, 230, 626, 28, 152, 709, 173, 275, 447, 248, 39, 936, 222, 543]
# Size of a neighbourhood: 12 instead of 10
# 	Neighbours: [709, 39, 217, 28, 447, 723, 435, 173, 275, 1, 255, 273]
# Size of a neighbourhood: 33 instead of 10
# 	Neighbours: [963, 786, 547, 19, 46, 921, 694, 534, 269, 551, 657, 408, 81, 625, 418, 636, 459, 66, 477, 877, 486, 467, 165, 710, 991, 928, 52, 222, 949, 476, 228, 443, 997]
# Size of a neighbourhood: 17 instead of 10
# 	Neighbours: [292, 75, 701, 205, 457, 330, 262, 501, 18, 711, 293, 72, 186, 146, 263, 429, 242]
# Size of a neighbourhood: 62 instead of 10
# 	Neighbours: [638, 751, 634, 161, 446, 546, 219, 468, 10, 578, 747, 278, 847, 20, 144, 300, 697, 908, 324, 285, 831, 403, 455, 500, 58, 854, 734, 603, 978, 888, 776, 440, 312, 824, 258, 556, 945, 379, 147, 327, 760, 953, 295, 679, 267, 64, 385, 276, 753, 459, 66, 196, 883, 80, 345, 931, 974, 842, 680, 180, 389, 579]
# Size of a neighbourhood: 11 instead of 10
# 	Neighbours: [786, 19, 997, 625, 269, 877, 963, 928, 949, 408, 40]
# Size of a neighbourhood: 14 instead of 10
# 	Neighbours: [572, 11, 695, 952, 746, 482, 770, 536, 504, 869, 896, 610, 347, 922]
# Size of a neighbourhood: 10 instead of 10
# 	Neighbours: [670, 125, 971, 621, 20, 939, 932, 185, 894, 484]
# Size of a neighbourhood: 15 instead of 10
# 	Neighbours: [641, 453, 128, 469, 854, 525, 978, 772, 893, 653, 404, 574, 329, 730, 265]
# Size of a neighbourhood: 10 instead of 10
# 	Neighbours: [491, 191, 349, 959, 788, 95, 242, 687, 829, 378]
# Size of a neighbourhood: 23 instead of 10
# 	Neighbours: [742, 868, 473, 712, 940, 791, 994, 53, 542, 270, 297, 514, 283, 269, 672, 625, 16, 493, 928, 6, 463, 164, 629]
# Size of a neighbourhood: 22 instead of 10
# 	Neighbours: [41, 566, 107, 284, 945, 578, 130, 884, 145, 313, 422, 776, 320, 553, 556, 9, 32, 673, 158, 805, 706, 627, 418, 88, 409, 870, 634, 147, 499, 653, 875, 254, 845, 299, 714, 327, 404, 339, 636, 408, 568, 961, 921, 530]
# Size of a neighbourhood: 17 instead of 10
# 	Neighbours: [120, 569, 630, 722, 451, 126, 261, 12, 1, 573, 142, 762, 862, 15, 936, 858, 934]
# Size of a neighbourhood: 35 instead of 10
# 	Neighbours: [192, 887, 641, 525, 224, 351, 107, 32, 421, 143, 651, 893, 52, 339, 574, 12, 142, 265, 152, 709, 329, 39, 486, 225, 230, 38, 813, 472, 958, 779, 530, 42, 7, 97, 63]
# Size of a neighbourhood: 25 instead of 10
# 	Neighbours: [999, 893, 950, 421, 187, 9, 525, 320, 23, 506, 352, 450, 394, 812, 51, 299, 553, 715, 366, 654, 772, 778, 406, 411, 787]
# Size of a neighbourhood: 21 instead of 10
# 	Neighbours: [844, 34, 822, 481, 278, 604, 79, 766, 539, 651, 840, 745, 25, 750, 50, 924, 229, 338, 930, 635, 993]
# Size of a neighbourhood: 22 instead of 10
# 	Neighbours: [314, 383, 855, 67, 847, 285, 416, 820, 461, 529, 94, 30, 747, 799, 201, 409, 167, 400, 407, 806, 810, 834]
# Size of a neighbourhood: 33 instead of 10
# 	Neighbours: [154, 627, 671, 97, 684, 478, 620, 706, 254, 653, 999, 553, 299, 845, 692, 568, 530, 63, 191, 843, 507, 32, 88, 887, 365, 158, 192, 951, 107, 202, 872, 886, 740]
# Size of a neighbourhood: 11 instead of 10
# 	Neighbours: [354, 231, 717, 959, 609, 702, 681, 377, 232, 519, 949]
# Size of a neighbourhood: 34 instead of 10
# 	Neighbours: [280, 18, 121, 292, 955, 728, 349, 33, 75, 44, 736, 537, 293, 659, 381, 701, 768, 146, 205, 875, 778, 437, 186, 952, 391, 902, 347, 733, 195, 340, 445, 482, 770, 491]
# Size of a neighbourhood: 11 instead of 10
# 	Neighbours: [145, 684, 395, 103, 97, 191, 671, 739, 752, 478, 101]
# Size of a neighbourhood: 66 instead of 10
# 	Neighbours: [159, 256, 115, 427, 399, 135, 894, 807, 331, 24, 901, 450, 451, 358, 275, 435, 69, 102, 276, 238, 185, 698, 370, 713, 234, 385, 196, 246, 480, 90, 769, 324, 716, 718, 0, 160, 726, 932, 259, 484, 803, 628, 183, 879, 860, 16, 836, 492, 939, 255, 792, 903, 211, 910, 433, 550, 527, 577, 974, 345, 214, 356, 223, 266, 606, 243]
# Size of a neighbourhood: 21 instead of 10
# 	Neighbours: [308, 391, 691, 295, 67, 94, 124, 909, 369, 462, 171, 305, 351, 601, 448, 317, 995, 576, 708, 723, 1]
# Size of a neighbourhood: 38 instead of 10
# 	Neighbours: [995, 341, 359, 837, 369, 582, 389, 596, 278, 367, 570, 603, 724, 420, 898, 382, 633, 363, 462, 517, 372, 171, 155, 614, 122, 869, 797, 795, 700, 271, 865, 953, 623, 178, 193, 675, 350, 817]
# Size of a neighbourhood: 11 instead of 10
# 	Neighbours: [170, 13, 353, 334, 368, 242, 649, 699, 768, 479, 919]
# Size of a neighbourhood: 16 instead of 10
# 	Neighbours: [933, 479, 786, 371, 426, 891, 716, 0, 149, 46, 803, 13, 567, 200, 214, 19]
# Size of a neighbourhood: 30 instead of 10
# 	Neighbours: [656, 13, 574, 329, 443, 641, 315, 128, 581, 911, 890, 265, 51, 893, 442, 768, 195, 580, 98, 426, 772, 888, 891, 371, 388, 957, 676, 479, 989, 659]
# Size of a neighbourhood: 33 instead of 10
# 	Neighbours: [698, 256, 606, 52, 151, 275, 486, 276, 238, 48, 20, 932, 371, 713, 234, 385, 196, 852, 246, 426, 490, 891, 90, 769, 159, 427, 894, 210, 357, 527, 974, 345, 318]
# Size of a neighbourhood: 10 instead of 10
# 	Neighbours: [785, 670, 689, 53, 151, 642, 868, 209, 384, 971]
# Size of a neighbourhood: 26 instead of 10
# 	Neighbours: [886, 627, 95, 62, 145, 478, 395, 154, 684, 714, 739, 287, 491, 620, 687, 671, 87, 959, 97, 752, 232, 829, 63, 872, 597, 706]
# Size of a neighbourhood: 21 instead of 10
# 	Neighbours: [974, 345, 698, 196, 276, 546, 185, 57, 486, 256, 371, 20, 52, 426, 753, 883, 891, 474, 318, 238, 357]
# Size of a neighbourhood: 12 instead of 10
# 	Neighbours: [659, 172, 884, 961, 537, 793, 169, 51, 319, 788, 29, 339]
# Size of a neighbourhood: 13 instead of 10
# 	Neighbours: [75, 205, 457, 501, 242, 330, 292, 227, 988, 322, 293, 828, 262]
# Size of a neighbourhood: 25 instead of 10
# 	Neighbours: [135, 592, 451, 679, 708, 134, 80, 269, 742, 69, 625, 386, 115, 92, 833, 807, 712, 836, 928, 987, 904, 448, 912, 629, 873]
# Size of a neighbourhood: 19 instead of 10
# 	Neighbours: [216, 663, 412, 827, 387, 452, 235, 63, 485, 597, 620, 867, 986, 464, 131, 703, 993, 890, 745]
# Size of a neighbourhood: 22 instead of 10
# 	Neighbours: [787, 716, 803, 715, 625, 450, 406, 269, 791, 283, 16, 266, 149, 928, 567, 778, 994, 115, 200, 760, 807, 676]
# Size of a neighbourhood: 14 instead of 10
# 	Neighbours: [476, 748, 421, 509, 53, 749, 791, 486, 453, 880, 450, 165, 52, 136]
# Size of a neighbourhood: 43 instead of 10
# 	Neighbours: [919, 368, 457, 501, 650, 378, 538, 322, 655, 988, 3, 814, 242, 364, 796, 828, 542, 396, 260, 143, 434, 840, 822, 262, 75, 589, 793, 869, 479, 428, 662, 701, 432, 205, 878, 229, 338, 993, 998, 522, 84, 959, 624]
# Size of a neighbourhood: 26 instead of 10
# 	Neighbours: [392, 133, 227, 538, 650, 878, 917, 322, 457, 501, 927, 988, 648, 163, 25, 522, 560, 396, 822, 72, 432, 334, 655, 998, 624, 814]
# Size of a neighbourhood: 21 instead of 10
# 	Neighbours: [354, 763, 705, 541, 262, 413, 123, 378, 687, 794, 164, 685, 902, 304, 373, 584, 377, 520, 519, 800, 754]
# Size of a neighbourhood: 10 instead of 10
# Size of a neighbourhood: 42 instead of 10
# 	Neighbours: [563, 655, 814, 878, 163, 714, 938, 853, 501, 988, 538, 923, 481, 107, 112, 381, 18, 511, 648, 392, 322, 650, 685, 4, 262, 54, 541, 187, 123, 687, 231, 227, 998, 624, 717, 959, 583, 360, 788, 457, 87, 62]
# Size of a neighbourhood: 22 instead of 10
# 	Neighbours: [663, 980, 867, 620, 128, 394, 559, 651, 589, 537, 659, 86, 485, 993, 984, 35, 497, 172, 207, 212, 412, 989]
# Size of a neighbourhood: 47 instead of 10
# 	Neighbours: [590, 569, 630, 753, 261, 116, 446, 341, 166, 76, 638, 120, 751, 385, 301, 12, 515, 142, 276, 694, 637, 644, 805, 566, 389, 675, 777, 576, 410, 812, 817, 466, 196, 848, 862, 866, 883, 15, 636, 596, 345, 931, 934, 228, 974, 951, 521]
# Size of a neighbourhood: 19 instead of 10
# 	Neighbours: [309, 112, 169, 619, 593, 369, 378, 724, 809, 268, 923, 100, 94, 804, 462, 10, 708, 218, 540]
# Size of a neighbourhood: 26 instead of 10
# 	Neighbours: [41, 46, 19, 786, 502, 410, 269, 328, 361, 625, 114, 997, 636, 329, 877, 833, 574, 177, 928, 40, 949, 261, 963, 265, 912, 975]
# Size of a neighbourhood: 13 instead of 10
# 	Neighbours: [302, 756, 325, 422, 871, 943, 734, 764, 140, 119, 484, 250, 673]
# Size of a neighbourhood: 27 instead of 10
# 	Neighbours: [411, 366, 654, 453, 128, 469, 749, 415, 776, 676, 880, 20, 394, 888, 318, 224, 812, 893, 778, 406, 450, 715, 787, 698, 426, 891, 371]
# Size of a neighbourhood: 19 instead of 10
# 	Neighbours: [695, 794, 846, 717, 511, 700, 165, 279, 488, 354, 21, 681, 685, 5, 476, 231, 865, 962, 122]
# Size of a neighbourhood: 41 instead of 10
# 	Neighbours: [317, 858, 593, 909, 332, 414, 601, 647, 573, 32, 689, 481, 67, 722, 634, 236, 536, 954, 971, 783, 500, 351, 706, 130, 390, 961, 651, 815, 531, 875, 308, 219, 12, 1, 723, 965, 691, 554, 790, 704, 785]
# Size of a neighbourhood: 11 instead of 10
# 	Neighbours: [13, 818, 364, 899, 128, 394, 812, 303, 105, 479, 571]
# Size of a neighbourhood: 50 instead of 10
# 	Neighbours: [517, 797, 121, 71, 955, 326, 331, 572, 161, 482, 869, 802, 153, 537, 271, 382, 760, 437, 168, 280, 283, 415, 372, 897, 926, 985, 238, 492, 817, 675, 92, 135, 16, 697, 144, 195, 990, 263, 200, 96, 577, 960, 795, 933, 111, 82, 800, 33, 526, 664]
# Size of a neighbourhood: 21 instead of 10
# 	Neighbours: [751, 630, 14, 472, 500, 566, 596, 722, 746, 747, 285, 805, 831, 858, 958, 58, 634, 166, 569, 261, 219]
# Size of a neighbourhood: 10 instead of 10
# 	Neighbours: [910, 171, 358, 120, 1, 679, 275, 936, 521, 102]
# Size of a neighbourhood: 13 instead of 10
# 	Neighbours: [497, 672, 6, 589, 415, 676, 428, 662, 844, 867, 283, 984, 206]
# Size of a neighbourhood: 23 instead of 10
# 	Neighbours: [461, 510, 416, 848, 285, 472, 652, 722, 747, 805, 958, 383, 941, 434, 201, 260, 929, 823, 179, 516, 969, 84, 325]
# Size of a neighbourhood: 26 instead of 10
# 	Neighbours: [124, 391, 570, 369, 167, 837, 752, 295, 804, 767, 359, 623, 582, 197, 809, 10, 952, 308, 707, 372, 795, 367, 342, 386, 350, 540]
# Size of a neighbourhood: 24 instead of 10
# 	Neighbours: [493, 977, 542, 518, 94, 706, 672, 6, 164, 651, 632, 265, 742, 574, 481, 329, 65, 641, 989, 236, 868, 790, 473, 785]
# Size of a neighbourhood: 28 instead of 10
# 	Neighbours: [365, 890, 880, 805, 31, 547, 555, 694, 657, 477, 942, 235, 228, 530, 827, 843, 671, 887, 107, 208, 430, 389, 749, 245, 192, 202, 412, 951]
# Size of a neighbourhood: 19 instead of 10
# 	Neighbours: [937, 677, 291, 692, 342, 540, 531, 952, 405, 104, 992, 307, 10, 101, 806, 197, 931, 425, 279]
# Size of a neighbourhood: 54 instead of 10
# 	Neighbours: [677, 821, 301, 12, 192, 444, 405, 730, 569, 126, 385, 9, 320, 1, 630, 142, 339, 52, 152, 698, 709, 358, 276, 265, 410, 26, 574, 329, 806, 425, 196, 893, 480, 39, 486, 351, 435, 345, 508, 931, 937, 974, 230, 357, 233, 127, 41, 965, 907, 63, 861, 950, 658, 887]
# Size of a neighbourhood: 52 instead of 10
# 	Neighbours: [547, 230, 152, 694, 328, 228, 282, 464, 158, 107, 720, 52, 558, 997, 555, 574, 76, 142, 265, 648, 273, 178, 656, 749, 657, 568, 361, 329, 459, 66, 821, 848, 880, 877, 486, 101, 639, 637, 235, 217, 934, 241, 40, 222, 963, 805, 313, 38, 530, 843, 365, 443]
# Size of a neighbourhood: 28 instead of 10
# 	Neighbours: [869, 955, 919, 11, 341, 359, 570, 47, 623, 770, 108, 542, 277, 155, 168, 475, 319, 750, 802, 795, 391, 504, 944, 896, 985, 922, 367, 926]
# Size of a neighbourhood: 44 instead of 10
# 	Neighbours: [370, 628, 932, 941, 223, 20, 324, 756, 758, 820, 403, 619, 943, 204, 48, 298, 544, 264, 929, 281, 488, 647, 165, 969, 673, 413, 164, 860, 971, 183, 962, 476, 781, 256, 275, 137, 427, 159, 210, 816, 606, 830, 348, 244]
# Size of a neighbourhood: 11 instead of 10
# 	Neighbours: [481, 923, 507, 236, 663, 545, 77, 172, 815, 187, 961]
# Size of a neighbourhood: 28 instead of 10
# 	Neighbours: [486, 357, 224, 165, 534, 476, 142, 69, 151, 152, 275, 694, 269, 997, 786, 625, 459, 748, 279, 836, 698, 46, 877, 928, 949, 228, 230, 19]
# Size of a neighbourhood: 40 instead of 10
# 	Neighbours: [705, 584, 378, 611, 18, 541, 231, 800, 538, 457, 501, 655, 672, 440, 58, 814, 381, 878, 455, 724, 685, 396, 219, 262, 511, 292, 793, 146, 123, 300, 763, 227, 717, 702, 680, 520, 263, 711, 354, 491]
# Size of a neighbourhood: 20 instead of 10
# 	Neighbours: [279, 413, 846, 859, 724, 531, 32, 489, 100, 737, 82, 247, 695, 941, 962, 370, 971, 122, 642, 685]
# Size of a neighbourhood: 10 instead of 10
# 	Neighbours: [758, 859, 505, 941, 971, 122, 724, 413, 846, 488]
# Size of a neighbourhood: 55 instead of 10
# 	Neighbours: [463, 868, 742, 632, 542, 65, 977, 236, 404, 518, 164, 514, 481, 56, 265, 473, 799, 785, 419, 421, 53, 317, 712, 277, 6, 568, 625, 74, 629, 574, 254, 329, 424, 651, 641, 269, 790, 361, 297, 94, 791, 270, 796, 989, 940, 845, 882, 672, 283, 16, 706, 928, 994, 833, 912]
# Size of a neighbourhood: 18 instead of 10
# 	Neighbours: [456, 586, 494, 22, 969, 905, 929, 756, 325, 823, 179, 125, 761, 932, 516, 713, 335, 731]
# Size of a neighbourhood: 16 instead of 10
# 	Neighbours: [765, 233, 811, 220, 552, 696, 708, 732, 173, 288, 447, 600, 806, 976, 524, 28]
# Size of a neighbourhood: 73 instead of 10
# 	Neighbours: [888, 284, 578, 825, 13, 119, 871, 760, 58, 729, 320, 506, 756, 379, 20, 901, 824, 673, 45, 759, 823, 440, 179, 146, 994, 479, 882, 404, 653, 566, 184, 409, 268, 123, 553, 715, 854, 546, 544, 9, 437, 781, 772, 778, 204, 798, 787, 875, 676, 776, 264, 147, 978, 328, 408, 361, 718, 149, 426, 371, 669, 716, 177, 891, 567, 803, 502, 195, 200, 214, 294, 169, 535]
# Size of a neighbourhood: 35 instead of 10
# 	Neighbours: [885, 446, 285, 504, 747, 858, 471, 751, 573, 278, 481, 416, 831, 722, 461, 954, 268, 604, 332, 536, 108, 414, 766, 161, 515, 64, 321, 862, 896, 922, 458, 529, 704, 11, 634]
# Size of a neighbourhood: 13 instead of 10
# 	Neighbours: [935, 783, 284, 23, 553, 141, 692, 307, 911, 35, 735, 581, 773]
# Size of a neighbourhood: 15 instead of 10
# 	Neighbours: [504, 11, 896, 475, 367, 570, 623, 471, 926, 500, 944, 831, 111, 869, 885]
# Size of a neighbourhood: 44 instead of 10
# 	Neighbours: [848, 416, 461, 529, 906, 652, 805, 325, 454, 285, 958, 383, 566, 107, 112, 286, 747, 714, 722, 472, 814, 88, 245, 516, 201, 260, 929, 434, 840, 758, 422, 823, 179, 303, 943, 969, 552, 84, 696, 273, 777, 89, 430, 941]
# Size of a neighbourhood: 14 instead of 10
# 	Neighbours: [461, 516, 416, 693, 22, 285, 747, 929, 969, 383, 325, 823, 179, 510]
# Size of a neighbourhood: 60 instead of 10
# 	Neighbours: [759, 689, 268, 672, 164, 542, 536, 737, 858, 182, 958, 481, 236, 514, 940, 971, 983, 414, 286, 805, 454, 652, 88, 796, 461, 510, 917, 500, 368, 277, 74, 94, 706, 529, 270, 6, 440, 994, 472, 297, 125, 822, 840, 416, 589, 823, 179, 838, 13, 993, 338, 762, 84, 919, 742, 493, 239, 463, 868, 65]
# Size of a neighbourhood: 20 instead of 10
# 	Neighbours: [377, 902, 763, 549, 681, 852, 490, 716, 115, 803, 33, 807, 757, 16, 71, 520, 373, 356, 800, 214]
# Size of a neighbourhood: 14 instead of 10
# 	Neighbours: [258, 389, 509, 749, 88, 880, 327, 130, 147, 134, 116, 15, 671, 636]
# Size of a neighbourhood: 25 instead of 10
# 	Neighbours: [976, 524, 732, 447, 233, 600, 28, 173, 1, 120, 696, 708, 709, 308, 576, 777, 12, 723, 336, 39, 480, 936, 451, 498, 521]
# Size of a neighbourhood: 28 instead of 10
# 	Neighbours: [192, 634, 291, 481, 7, 224, 107, 453, 749, 880, 295, 421, 128, 51, 893, 555, 574, 76, 265, 692, 329, 459, 730, 931, 641, 530, 887, 127]
# Size of a neighbourhood: 16 instead of 10
# 	Neighbours: [649, 155, 176, 257, 569, 14, 335, 139, 630, 142, 218, 727, 731, 905, 353, 466]
# Size of a neighbourhood: 10 instead of 10
# 	Neighbours: [461, 529, 693, 285, 747, 799, 383, 510, 516, 314]
# Size of a neighbourhood: 48 instead of 10
# 	Neighbours: [554, 273, 107, 714, 620, 286, 525, 749, 880, 805, 923, 706, 254, 651, 840, 884, 422, 845, 574, 576, 265, 696, 709, 510, 694, 568, 329, 848, 39, 101, 77, 980, 241, 228, 641, 127, 481, 112, 207, 2, 938, 478, 887, 365, 430, 245, 192, 650]
# Size of a neighbourhood: 25 instead of 10
# 	Neighbours: [414, 640, 285, 446, 500, 747, 751, 722, 858, 236, 947, 130, 300, 419, 240, 755, 775, 804, 108, 661, 909, 746, 116, 610, 166]
# Size of a neighbourhood: 21 instead of 10
# 	Neighbours: [277, 74, 6, 796, 108, 368, 518, 380, 840, 822, 589, 744, 283, 338, 993, 919, 742, 493, 463, 868, 65]
# Size of a neighbourhood: 41 instead of 10
# 	Neighbours: [248, 626, 217, 756, 298, 281, 434, 260, 606, 25, 143, 651, 929, 122, 871, 932, 662, 308, 628, 941, 969, 251, 559, 171, 206, 183, 256, 338, 152, 709, 275, 713, 39, 383, 936, 230, 38, 42, 597, 213, 782]
# Size of a neighbourhood: 25 instead of 10
# 	Neighbours: [655, 432, 461, 516, 529, 22, 416, 878, 330, 988, 929, 969, 456, 4, 494, 187, 586, 617, 853, 814, 325, 510, 823, 179, 262]
# Size of a neighbourhood: 18 instead of 10
# 	Neighbours: [902, 851, 406, 352, 366, 411, 939, 763, 654, 33, 738, 280, 450, 715, 787, 519, 886, 879]
# Size of a neighbourhood: 21 instead of 10
# 	Neighbours: [135, 331, 437, 760, 901, 159, 115, 259, 399, 807, 324, 210, 211, 873, 842, 433, 734, 96, 243, 266, 577]
# Size of a neighbourhood: 58 instead of 10
# 	Neighbours: [284, 692, 32, 578, 653, 999, 23, 556, 187, 481, 627, 706, 737, 332, 945, 799, 128, 320, 581, 107, 10, 559, 22, 516, 20, 776, 422, 13, 184, 154, 888, 768, 45, 893, 9, 507, 379, 499, 147, 531, 687, 634, 525, 88, 119, 299, 875, 882, 693, 404, 158, 730, 103, 35, 470, 145, 97, 503]
# Size of a neighbourhood: 13 instead of 10
# 	Neighbours: [931, 525, 355, 574, 76, 265, 267, 692, 329, 459, 730, 235, 866]
# Size of a neighbourhood: 10 instead of 10
# 	Neighbours: [92, 915, 647, 419, 70, 78, 505, 621, 725, 414]
# Size of a neighbourhood: 35 instead of 10
# 	Neighbours: [34, 539, 604, 908, 50, 439, 924, 312, 471, 500, 132, 64, 66, 278, 70, 704, 783, 750, 174, 745, 885, 86, 172, 911, 834, 915, 111, 144, 986, 402, 319, 639, 161, 664, 362]
# Size of a neighbourhood: 8 instead of 10
# 	Neighbours: [567, 778, 891, 716, 214, 803, 426, 427]
# Size of a neighbourhood: 29 instead of 10
# 	Neighbours: [462, 837, 359, 623, 367, 475, 285, 369, 341, 504, 747, 585, 582, 124, 831, 11, 372, 155, 869, 761, 391, 218, 862, 944, 896, 926, 350, 458, 922]
# Size of a neighbourhood: 30 instead of 10
# 	Neighbours: [858, 11, 500, 504, 954, 996, 14, 983, 593, 601, 414, 441, 155, 869, 338, 120, 569, 630, 762, 896, 985, 922, 521, 471, 885, 914, 790, 82, 722, 704]
# Size of a neighbourhood: 65 instead of 10
# 	Neighbours: [265, 329, 641, 997, 410, 877, 101, 328, 192, 428, 768, 525, 52, 7, 555, 378, 261, 76, 12, 142, 107, 453, 152, 84, 708, 709, 273, 178, 694, 692, 269, 568, 361, 625, 786, 656, 459, 39, 440, 486, 368, 730, 371, 426, 98, 891, 833, 46, 493, 699, 928, 931, 937, 949, 19, 228, 230, 904, 51, 912, 127, 530, 989, 887, 957]
# Size of a neighbourhood: 14 instead of 10
# 	Neighbours: [559, 957, 745, 35, 355, 911, 516, 184, 422, 580, 98, 503, 73, 346]
# Size of a neighbourhood: 23 instead of 10
# 	Neighbours: [496, 95, 973, 525, 7, 378, 112, 714, 923, 462, 10, 540, 141, 481, 101, 937, 274, 878, 641, 127, 291, 938, 964]
# Size of a neighbourhood: 20 instead of 10
# 	Neighbours: [456, 586, 494, 22, 969, 905, 929, 756, 325, 823, 826, 179, 892, 125, 761, 932, 516, 713, 335, 731]
# Size of a neighbourhood: 15 instead of 10
# 	Neighbours: [980, 840, 759, 479, 148, 690, 397, 125, 802, 838, 744, 338, 984, 497, 993]
# Size of a neighbourhood: 56 instead of 10
# 	Neighbours: [157, 240, 890, 315, 925, 740, 605, 743, 666, 791, 558, 631, 994, 182, 542, 661, 277, 380, 31, 825, 13, 479, 760, 404, 715, 895, 798, 787, 261, 282, 116, 269, 657, 361, 625, 495, 849, 866, 716, 0, 942, 467, 833, 803, 177, 991, 928, 235, 912, 956, 214, 17, 368, 208, 294, 74]
# Size of a neighbourhood: 23 instead of 10
# 	Neighbours: [341, 831, 14, 746, 375, 504, 367, 623, 155, 10, 359, 515, 805, 566, 446, 751, 170, 755, 420, 393, 817, 466, 675]
# Size of a neighbourhood: 11 instead of 10
# 	Neighbours: [63, 782, 709, 39, 42, 95, 606, 62, 887, 192, 658]
# Size of a neighbourhood: 32 instead of 10
# 	Neighbours: [621, 892, 48, 745, 759, 184, 581, 106, 264, 415, 971, 161, 844, 776, 672, 20, 888, 132, 125, 544, 697, 932, 204, 943, 867, 738, 984, 185, 497, 710, 635, 773]
# Size of a neighbourhood: 49 instead of 10
# 	Neighbours: [921, 694, 408, 786, 19, 228, 46, 749, 52, 547, 997, 638, 178, 880, 533, 134, 534, 80, 116, 269, 657, 568, 523, 69, 625, 389, 476, 459, 877, 486, 637, 753, 418, 836, 8, 928, 241, 40, 949, 327, 963, 165, 975, 41, 232, 162, 671, 365, 870]
# Size of a neighbourhood: 20 instead of 10
# 	Neighbours: [296, 180, 104, 33, 591, 798, 534, 80, 386, 466, 417, 402, 223, 830, 861, 846, 202, 468, 767, 154]
# Size of a neighbourhood: 28 instead of 10
# 	Neighbours: [155, 14, 528, 623, 472, 958, 831, 425, 736, 7, 596, 341, 176, 143, 746, 569, 367, 139, 630, 142, 727, 731, 218, 699, 905, 337, 417, 813]
# Size of a neighbourhood: 13 instead of 10
# 	Neighbours: [322, 650, 998, 624, 392, 227, 457, 501, 655, 853, 878, 927, 988]
# Size of a neighbourhood: 40 instead of 10
# 	Neighbours: [601, 338, 192, 248, 351, 543, 25, 587, 132, 481, 663, 387, 79, 31, 316, 874, 460, 281, 260, 143, 308, 971, 298, 434, 626, 840, 822, 844, 317, 983, 339, 993, 151, 709, 762, 39, 980, 785, 887, 127]
# Size of a neighbourhood: 25 instead of 10
# 	Neighbours: [404, 978, 854, 51, 32, 994, 553, 485, 403, 13, 882, 94, 687, 977, 656, 184, 107, 798, 888, 440, 265, 574, 329, 641, 730]
# Size of a neighbourhood: 11 instead of 10
# 	Neighbours: [942, 464, 694, 534, 269, 895, 568, 625, 928, 228, 547]
# Size of a neighbourhood: 11 instead of 10
# 	Neighbours: [301, 63, 468, 189, 12, 351, 597, 739, 887, 192, 444]
# Size of a neighbourhood: 12 instead of 10
# 	Neighbours: [905, 358, 540, 126, 139, 309, 731, 821, 193, 936, 903, 217]
# Size of a neighbourhood: 12 instead of 10
# 	Neighbours: [495, 472, 14, 737, 775, 846, 907, 414, 201, 992, 337, 958]
# Size of a neighbourhood: 38 instead of 10
# 	Neighbours: [238, 771, 331, 144, 397, 48, 324, 690, 515, 537, 86, 125, 697, 802, 444, 546, 276, 985, 858, 185, 920, 385, 196, 480, 492, 471, 554, 885, 195, 318, 577, 974, 345, 601, 573, 161, 526, 243]
# Size of a neighbourhood: 39 instead of 10
# 	Neighbours: [431, 105, 438, 789, 72, 36, 917, 310, 128, 330, 387, 394, 581, 442, 621, 808, 575, 598, 659, 580, 184, 818, 892, 163, 432, 303, 738, 774, 352, 876, 571, 490, 226, 465, 503, 106, 745, 412, 343]
# Size of a neighbourhood: 19 instead of 10
# 	Neighbours: [299, 145, 315, 605, 743, 558, 594, 254, 31, 663, 387, 311, 323, 631, 863, 845, 555, 942, 741]
# Size of a neighbourhood: 50 instead of 10
# 	Neighbours: [253, 642, 185, 48, 894, 492, 939, 384, 151, 190, 606, 621, 415, 78, 318, 23, 427, 726, 238, 932, 698, 379, 348, 53, 125, 16, 526, 971, 331, 628, 484, 966, 764, 497, 984, 773, 933, 160, 183, 860, 450, 792, 159, 20, 210, 256, 990, 851, 283, 879]
# Size of a neighbourhood: 7 instead of 10
# 	Neighbours: [949, 232, 749, 509, 88, 694, 523]
# Size of a neighbourhood: 54 instead of 10
# 	Neighbours: [20, 546, 379, 484, 24, 726, 526, 320, 219, 403, 48, 324, 820, 776, 825, 888, 932, 390, 45, 9, 764, 476, 147, 700, 165, 304, 409, 119, 118, 647, 271, 413, 506, 628, 865, 875, 760, 792, 846, 450, 798, 276, 698, 385, 196, 474, 661, 200, 318, 577, 974, 830, 861, 345]
# Size of a neighbourhood: 35 instead of 10
# 	Neighbours: [685, 5, 717, 519, 563, 53, 370, 846, 511, 52, 998, 624, 151, 748, 275, 534, 269, 742, 69, 625, 962, 486, 852, 159, 279, 616, 377, 757, 836, 894, 210, 928, 881, 360, 903]
# Size of a neighbourhood: 17 instead of 10
# 	Neighbours: [384, 670, 253, 77, 145, 671, 478, 951, 706, 977, 703, 348, 202, 154, 872, 620, 423]
# Size of a neighbourhood: 33 instead of 10
# 	Neighbours: [947, 962, 563, 584, 5, 763, 681, 231, 354, 828, 814, 881, 878, 994, 378, 370, 270, 846, 511, 514, 609, 541, 705, 413, 549, 373, 902, 717, 940, 377, 360, 519, 655]
# Size of a neighbourhood: 15 instead of 10
# 	Neighbours: [190, 858, 958, 971, 983, 518, 737, 472, 182, 414, 125, 323, 762, 785, 338]
# Size of a neighbourhood: 25 instead of 10
# 	Neighbours: [161, 300, 883, 500, 278, 971, 144, 858, 485, 908, 324, 219, 390, 45, 515, 546, 734, 672, 48, 172, 647, 536, 64, 238, 953]
# Size of a neighbourhood: 14 instead of 10
# 	Neighbours: [211, 120, 576, 261, 1, 410, 679, 84, 451, 834, 862, 521, 904, 936]
# Size of a neighbourhood: 25 instead of 10
# 	Neighbours: [709, 941, 28, 597, 260, 308, 782, 248, 217, 626, 298, 275, 281, 447, 1, 273, 173, 192, 543, 651, 434, 137, 42, 127, 887]
# Size of a neighbourhood: 28 instead of 10
# 	Neighbours: [791, 629, 266, 748, 767, 770, 509, 796, 828, 994, 53, 370, 609, 662, 902, 715, 787, 269, 742, 625, 115, 807, 928, 904, 211, 453, 868, 65]
# Size of a neighbourhood: 32 instead of 10
# 	Neighbours: [107, 627, 706, 886, 236, 947, 962, 805, 814, 88, 510, 158, 378, 112, 923, 94, 254, 799, 32, 563, 481, 130, 270, 422, 845, 738, 56, 568, 273, 530, 478, 232]
# Size of a neighbourhood: 14 instead of 10
# 	Neighbours: [214, 450, 152, 361, 698, 159, 716, 686, 506, 803, 757, 210, 230, 894]
# Size of a neighbourhood: 57 instead of 10
# 	Neighbours: [521, 747, 285, 775, 858, 909, 201, 120, 414, 573, 661, 689, 416, 737, 446, 14, 461, 954, 958, 419, 67, 500, 647, 724, 820, 941, 300, 619, 529, 510, 370, 129, 260, 434, 929, 536, 308, 171, 219, 324, 969, 250, 451, 569, 126, 1, 630, 751, 723, 862, 15, 936, 472, 588, 691, 640, 458]
# Size of a neighbourhood: 40 instead of 10
# 	Neighbours: [966, 792, 238, 185, 673, 492, 508, 933, 894, 670, 24, 358, 151, 533, 643, 276, 644, 397, 48, 698, 256, 839, 385, 196, 474, 159, 764, 427, 399, 879, 16, 390, 484, 710, 210, 628, 974, 939, 647, 345]
# Size of a neighbourhood: 40 instead of 10
# 	Neighbours: [12, 7, 351, 425, 192, 381, 634, 291, 224, 525, 593, 18, 601, 603, 295, 531, 952, 733, 421, 10, 219, 308, 251, 155, 444, 893, 301, 339, 569, 139, 14, 1, 630, 410, 931, 965, 127, 658, 887, 779]
# Size of a neighbourhood: 33 instead of 10
# 	Neighbours: [658, 97, 301, 531, 556, 63, 526, 945, 444, 379, 875, 591, 351, 12, 677, 15, 965, 691, 618, 597, 189, 491, 615, 736, 191, 145, 887, 82, 32, 752, 154, 468, 192]
# Size of a neighbourhood: 15 instead of 10
# 	Neighbours: [743, 849, 315, 25, 558, 631, 666, 594, 31, 434, 260, 628, 741, 946, 863]
# Size of a neighbourhood: 13 instead of 10
# 	Neighbours: [14, 596, 831, 446, 751, 504, 367, 727, 623, 341, 10, 155, 166]
# Size of a neighbourhood: 10 instead of 10
# 	Neighbours: [747, 458, 446, 461, 500, 529, 416, 722, 862, 751]
# Size of a neighbourhood: 18 instead of 10
# 	Neighbours: [749, 209, 509, 523, 748, 476, 791, 224, 453, 365, 366, 654, 406, 411, 469, 228, 671, 694]
# Size of a neighbourhood: 39 instead of 10
# 	Neighbours: [751, 831, 500, 747, 285, 634, 885, 504, 529, 416, 623, 461, 746, 367, 722, 472, 858, 958, 14, 566, 596, 805, 58, 295, 166, 312, 10, 219, 45, 569, 261, 76, 630, 638, 862, 866, 458, 471, 931]
# Size of a neighbourhood: 11 instead of 10
# 	Neighbours: [520, 541, 280, 902, 763, 377, 349, 231, 800, 354, 519]
# Size of a neighbourhood: 27 instead of 10
# 	Neighbours: [775, 382, 596, 14, 972, 359, 515, 853, 814, 504, 341, 146, 804, 536, 992, 591, 414, 746, 831, 420, 130, 250, 770, 584, 337, 417, 116]
# Size of a neighbourhood: 72 instead of 10
# ...
# Size of a neighbourhood: 35 instead of 10
# 	Neighbours: [314, 909, 810, 416, 461, 481, 529, 634, 747, 847, 855, 332, 67, 94, 140, 940, 236, 285, 130, 784, 419, 355, 804, 370, 124, 383, 514, 167, 882, 693, 901, 435, 806, 873, 632]
# Size of a neighbourhood: 24 instead of 10
# 	Neighbours: [826, 580, 765, 900, 288, 600, 678, 708, 732, 498, 811, 780, 73, 480, 98, 61, 138, 220, 967, 976, 524, 960, 346, 957]
# Size of a neighbourhood: 39 instead of 10
# 	Neighbours: [163, 54, 988, 381, 198, 186, 310, 330, 655, 322, 927, 392, 205, 242, 72, 75, 457, 501, 701, 538, 62, 378, 18, 128, 648, 133, 293, 432, 287, 774, 187, 511, 560, 609, 229, 788, 938, 36, 602]
# Size of a neighbourhood: 17 instead of 10
# 	Neighbours: [806, 30, 498, 540, 600, 400, 405, 407, 847, 220, 233, 964, 290, 704, 60, 79, 109]
# Size of a neighbourhood: 65 instead of 10
# 	Neighbours: [162, 476, 647, 165, 305, 41, 619, 408, 830, 971, 695, 6, 413, 164, 748, 962, 881, 53, 370, 171, 219, 281, 176, 298, 700, 996, 673, 484, 628, 865, 820, 451, 52, 339, 358, 151, 275, 723, 137, 224, 69, 786, 636, 486, 726, 46, 836, 8, 508, 19, 975, 390, 588, 38, 603, 941, 813, 873, 642, 433, 244, 913, 190, 622, 290]
# Size of a neighbourhood: 14 instead of 10
# 	Neighbours: [844, 750, 315, 25, 132, 542, 840, 635, 589, 917, 368, 993, 919, 338]
# Size of a neighbourhood: 15 instead of 10
# 	Neighbours: [179, 0, 969, 325, 759, 91, 516, 693, 13, 882, 871, 544, 204, 264, 781]
# Size of a neighbourhood: 65 instead of 10
# 	Neighbours: [13, 9, 759, 823, 479, 179, 888, 146, 320, 446, 368, 661, 751, 578, 516, 201, 397, 20, 515, 325, 776, 262, 589, 854, 264, 472, 91, 958, 566, 440, 978, 268, 676, 950, 871, 184, 805, 125, 544, 802, 772, 204, 546, 58, 812, 45, 838, 969, 170, 499, 673, 760, 798, 26, 261, 644, 393, 371, 426, 891, 474, 177, 157, 890, 195]
# Size of a neighbourhood: 17 instead of 10
# 	Neighbours: [560, 609, 501, 198, 457, 796, 988, 538, 322, 74, 927, 242, 75, 701, 902, 227, 205]
# Size of a neighbourhood: 35 instead of 10
# 	Neighbours: [136, 476, 403, 165, 921, 357, 223, 786, 19, 46, 20, 486, 52, 861, 468, 978, 469, 318, 202, 854, 637, 698, 348, 384, 253, 506, 224, 628, 673, 484, 870, 225, 748, 450, 200]
# Size of a neighbourhood: 22 instead of 10
# 	Neighbours: [14, 596, 623, 10, 446, 504, 746, 367, 751, 500, 634, 11, 285, 341, 570, 747, 155, 727, 866, 466, 922, 896]
# Size of a neighbourhood: 27 instead of 10
# 	Neighbours: [170, 890, 334, 835, 368, 13, 479, 768, 315, 919, 678, 353, 699, 63, 95, 212, 17, 216, 62, 827, 242, 914, 649, 973, 951, 29, 981]
# Size of a neighbourhood: 10 instead of 10
# 	Neighbours: [350, 124, 767, 582, 462, 391, 372, 570, 386, 795]
# Size of a neighbourhood: 61 instead of 10
# 	Neighbours: [300, 171, 995, 679, 451, 243, 941, 278, 455, 285, 619, 603, 582, 308, 281, 837, 219, 298, 662, 614, 722, 324, 734, 747, 953, 64, 724, 358, 120, 576, 608, 1, 400, 638, 820, 708, 275, 134, 834, 862, 102, 936, 521, 987, 904, 211, 350, 458, 873, 847, 779, 691, 680, 640, 910, 433, 550, 290, 389, 245, 430]
# Size of a neighbourhood: 41 instead of 10
# 	Neighbours: [635, 672, 452, 132, 6, 822, 662, 867, 428, 278, 542, 281, 651, 298, 840, 453, 589, 415, 676, 368, 971, 868, 750, 440, 206, 283, 338, 993, 997, 919, 151, 742, 81, 984, 877, 497, 241, 904, 164, 443, 65]
# Size of a neighbourhood: 52 instead of 10
# 	Neighbours: [510, 552, 84, 273, 777, 696, 245, 805, 906, 260, 434, 840, 325, 120, 461, 576, 126, 76, 608, 142, 28, 407, 529, 416, 709, 731, 732, 286, 173, 762, 275, 652, 447, 694, 454, 849, 862, 239, 39, 780, 713, 234, 590, 89, 217, 241, 228, 521, 905, 527, 430, 904]
# Size of a neighbourhood: 12 instead of 10
# 	Neighbours: [814, 650, 510, 322, 655, 392, 805, 878, 545, 325, 262, 4]
# Size of a neighbourhood: 47 instead of 10
# 	Neighbours: [473, 270, 215, 382, 278, 940, 130, 536, 419, 53, 108, 306, 523, 647, 514, 572, 414, 168, 897, 851, 317, 64, 995, 533, 134, 80, 116, 742, 69, 636, 483, 879, 836, 241, 968, 211, 162, 873, 65, 554, 550, 96, 463, 868, 389, 209, 327]
# Size of a neighbourhood: 18 instead of 10
# 	Neighbours: [183, 427, 606, 628, 781, 841, 778, 136, 725, 863, 932, 939, 450, 256, 159, 399, 210, 484]
# Size of a neighbourhood: 24 instead of 10
# 	Neighbours: [122, 582, 281, 298, 905, 724, 585, 25, 133, 941, 488, 837, 171, 248, 363, 260, 543, 434, 626, 662, 731, 275, 222, 218]
# Size of a neighbourhood: 21 instead of 10
# 	Neighbours: [865, 155, 337, 736, 351, 341, 603, 582, 618, 531, 952, 733, 251, 623, 367, 165, 118, 271, 139, 975, 14]
# Size of a neighbourhood: 23 instead of 10
# 	Neighbours: [387, 589, 890, 822, 663, 415, 759, 537, 659, 676, 479, 844, 802, 838, 452, 206, 283, 984, 497, 980, 956, 989, 669]
# Size of a neighbourhood: 46 instead of 10
# 	Neighbours: [919, 482, 750, 802, 319, 573, 858, 268, 341, 359, 368, 570, 601, 604, 623, 108, 542, 277, 396, 166, 766, 441, 155, 840, 168, 822, 589, 537, 475, 500, 504, 278, 227, 338, 993, 367, 261, 944, 896, 985, 926, 922, 471, 790, 11, 885]
# Size of a neighbourhood: 37 instead of 10
# 	Neighbours: [204, 264, 823, 756, 544, 179, 169, 58, 759, 91, 516, 825, 383, 13, 324, 888, 325, 932, 422, 943, 146, 734, 969, 206, 123, 499, 409, 781, 437, 882, 246, 669, 98, 90, 957, 213, 769]
# Size of a neighbourhood: 20 instead of 10
# 	Neighbours: [658, 351, 219, 546, 556, 945, 32, 531, 379, 444, 909, 67, 419, 591, 634, 130, 327, 12, 965, 301]
# Size of a neighbourhood: 29 instead of 10
# 	Neighbours: [808, 229, 36, 878, 538, 853, 392, 648, 106, 186, 133, 272, 54, 72, 665, 257, 561, 163, 925, 998, 624, 717, 150, 946, 683, 852, 226, 503, 602]
# Size of a neighbourhood: 16 instead of 10
# 	Neighbours: [880, 365, 107, 286, 453, 525, 224, 805, 366, 411, 469, 654, 812, 228, 530, 694]
# Size of a neighbourhood: 15 instead of 10
# 	Neighbours: [685, 511, 681, 5, 748, 563, 584, 53, 360, 609, 549, 902, 962, 828, 717]
# Size of a neighbourhood: 34 instead of 10
# 	Neighbours: [412, 479, 13, 315, 589, 759, 91, 823, 825, 179, 368, 676, 594, 184, 888, 772, 812, 838, 867, 849, 371, 426, 891, 177, 235, 212, 827, 832, 208, 464, 951, 745, 31, 29]
# Size of a neighbourhood: 14 instead of 10
# 	Neighbours: [621, 125, 745, 48, 835, 850, 690, 515, 598, 759, 858, 969, 789, 397]
# Size of a neighbourhood: 24 instead of 10
# 	Neighbours: [128, 105, 192, 421, 525, 7, 20, 366, 411, 51, 654, 444, 772, 812, 224, 999, 506, 450, 698, 474, 127, 63, 887, 318]
# Size of a neighbourhood: 24 instead of 10
# 	Neighbours: [668, 850, 759, 239, 586, 494, 617, 489, 148, 262, 589, 170, 823, 826, 179, 580, 13, 22, 892, 125, 456, 838, 919, 303]
# Size of a neighbourhood: 21 instead of 10
# 	Neighbours: [433, 855, 619, 516, 693, 284, 578, 324, 847, 161, 824, 932, 45, 734, 544, 437, 781, 204, 943, 264, 484]
# Size of a neighbourhood: 34 instead of 10
# 	Neighbours: [21, 905, 649, 260, 434, 586, 494, 617, 456, 126, 528, 137, 624, 998, 142, 660, 120, 709, 775, 218, 762, 275, 488, 84, 678, 39, 279, 713, 848, 353, 217, 521, 122, 903]
# Size of a neighbourhood: 15 instead of 10
# 	Neighbours: [704, 278, 455, 604, 172, 500, 161, 144, 319, 86, 64, 562, 885, 174, 471]
# Size of a neighbourhood: 20 instead of 10
# 	Neighbours: [266, 712, 305, 662, 408, 8, 904, 211, 816, 629, 502, 868, 619, 290, 109, 430, 592, 245, 169, 622]
# Size of a neighbourhood: 24 instead of 10
# 	Neighbours: [49, 348, 224, 509, 758, 859, 488, 476, 712, 748, 53, 370, 281, 841, 298, 311, 860, 275, 941, 688, 37, 970, 642, 222]
# Size of a neighbourhood: 25 instead of 10
# 	Neighbours: [896, 11, 475, 466, 504, 926, 500, 797, 831, 707, 869, 367, 944, 321, 64, 985, 570, 862, 623, 517, 353, 471, 955, 111, 885]
# Size of a neighbourhood: 24 instead of 10
# 	Neighbours: [923, 101, 107, 714, 512, 510, 378, 481, 309, 596, 398, 7, 805, 814, 593, 706, 10, 422, 273, 178, 369, 583, 530, 103]
# Size of a neighbourhood: 16 instead of 10
# 	Neighbours: [625, 928, 214, 534, 791, 742, 361, 994, 786, 877, 716, 46, 803, 949, 19, 997]
# Size of a neighbourhood: 31 instead of 10
# 	Neighbours: [969, 416, 529, 722, 472, 758, 941, 958, 510, 652, 545, 516, 201, 456, 260, 4, 42, 403, 756, 586, 494, 617, 434, 325, 823, 179, 125, 129, 461, 713, 932]
# Size of a neighbourhood: 47 instead of 10
# 	Neighbours: [524, 288, 120, 1, 834, 217, 521, 976, 451, 910, 543, 569, 576, 126, 600, 139, 12, 171, 630, 28, 660, 679, 152, 708, 709, 732, 173, 275, 777, 447, 49, 723, 37, 821, 308, 862, 39, 102, 480, 251, 626, 722, 975, 358, 248, 233, 230]
# Size of a neighbourhood: 24 instead of 10
# 	Neighbours: [657, 464, 895, 994, 311, 671, 749, 694, 534, 748, 568, 380, 625, 254, 269, 791, 270, 228, 880, 406, 365, 845, 928, 547]
# Size of a neighbourhood: 78 instead of 10
# 	Neighbours: [202, 29, 812, 637, 805, 469, 365, 620, 286, 749, 880, 454, 364, 368, 88, 380, 143, 929, 403, 840, 366, 411, 325, 776, 472, 854, 51, 978, 13, 479, 654, 303, 958, 76, 142, 694, 848, 639, 77, 730, 899, 571, 393, 89, 228, 813, 530, 357, 921, 174, 438, 63, 216, 832, 843, 145, 375, 671, 887, 510, 430, 389, 464, 245, 192, 566, 402, 684, 830, 861, 213, 107, 154, 468, 180, 872, 890, 558]
# Size of a neighbourhood: 51 instead of 10
# 	Neighbours: [445, 869, 802, 896, 926, 985, 922, 482, 71, 11, 589, 292, 826, 475, 504, 146, 838, 319, 668, 153, 537, 121, 326, 919, 261, 47, 466, 770, 761, 238, 492, 817, 590, 644, 675, 393, 565, 669, 92, 177, 135, 16, 517, 0, 353, 797, 515, 960, 933, 989, 759]
# Size of a neighbourhood: 38 instead of 10
# 	Neighbours: [769, 193, 246, 90, 839, 100, 204, 206, 26, 358, 540, 400, 660, 372, 376, 683, 256, 371, 817, 234, 532, 264, 426, 98, 675, 490, 891, 121, 544, 160, 115, 807, 135, 71, 903, 527, 957, 904]
# Size of a neighbourhood: 31 instead of 10
# 	Neighbours: [815, 593, 485, 181, 996, 619, 390, 481, 398, 268, 923, 601, 979, 419, 309, 172, 578, 858, 4, 971, 651, 929, 403, 48, 690, 199, 125, 591, 77, 42, 339]
# Size of a neighbourhood: 7 instead of 10
# 	Neighbours: [41, 69, 636, 15, 965, 723, 836]
# Size of a neighbourhood: 22 instead of 10
# 	Neighbours: [207, 497, 620, 984, 387, 422, 589, 537, 659, 86, 303, 299, 744, 559, 77, 103, 780, 35, 651, 840, 989, 148]
# Size of a neighbourhood: 15 instead of 10
# 	Neighbours: [402, 412, 843, 394, 967, 443, 864, 202, 645, 365, 547, 464, 832, 178, 827]
# Size of a neighbourhood: 32 instead of 10
# 	Neighbours: [761, 926, 955, 914, 14, 155, 573, 593, 11, 896, 922, 475, 125, 771, 858, 397, 586, 815, 517, 797, 617, 456, 869, 802, 515, 504, 238, 690, 494, 335, 664, 353]
# Size of a neighbourhood: 60 instead of 10
# 	Neighbours: [604, 766, 720, 321, 439, 704, 180, 620, 996, 268, 452, 707, 79, 475, 578, 34, 312, 908, 161, 144, 961, 690, 86, 824, 924, 344, 64, 405, 383, 834, 562, 35, 669, 274, 471, 885, 964, 174, 535, 63, 95, 212, 597, 216, 658, 481, 500, 790, 111, 278, 512, 810, 11, 573, 213, 539, 745, 729, 664, 169]
# Size of a neighbourhood: 20 instead of 10
# 	Neighbours: [134, 259, 300, 358, 608, 400, 679, 275, 49, 533, 502, 376, 160, 855, 8, 949, 232, 904, 211, 451]
# Size of a neighbourhood: 41 instead of 10
# 	Neighbours: [537, 35, 98, 957, 669, 620, 802, 838, 574, 405, 265, 410, 708, 329, 77, 644, 238, 415, 185, 371, 980, 246, 426, 480, 759, 589, 490, 891, 90, 769, 474, 16, 493, 195, 659, 207, 933, 966, 790, 169, 86]
# Size of a neighbourhood: 15 instead of 10
# 	Neighbours: [445, 514, 161, 144, 283, 939, 792, 851, 901, 879, 16, 894, 96, 577, 940]
# Size of a neighbourhood: 22 instead of 10
# 	Neighbours: [116, 968, 203, 661, 104, 380, 43, 552, 528, 178, 596, 568, 495, 193, 101, 470, 188, 937, 903, 755, 337, 341]
# Size of a neighbourhood: 51 instead of 10
# 	Neighbours: [928, 791, 269, 625, 440, 868, 712, 940, 748, 947, 656, 962, 240, 672, 370, 270, 846, 297, 514, 854, 978, 428, 888, 760, 404, 715, 798, 787, 997, 534, 453, 657, 742, 361, 509, 786, 877, 716, 942, 467, 46, 803, 164, 40, 949, 19, 963, 65, 443, 214, 629]
# Size of a neighbourhood: 24 instead of 10
# 	Neighbours: [877, 904, 428, 328, 52, 453, 574, 265, 694, 269, 625, 786, 329, 459, 440, 486, 371, 426, 891, 46, 928, 19, 228, 949]
# Fingerprint inserted.
# 	fingerprinted dataset written to: schemes/categorical_neighbourhood/fingerprinted_datasets/german_credit_1_2_0.csv
# Time: 2 sec.
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\tsarcevic\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# True

# %%
fingerprinted_data, primary_key = import_fingerprinted_dataset("categorical_neighbourhood", "german_credit", [1, 2], 0)
# Out:
# Dataset: schemes/categorical_neighbourhood/fingerprinted_datasets/german_credit_1_2_0.csv

# %%
sns.set(style="ticks")
fig1, ax1 = plt.subplots(2, 4, figsize=(12.5,6))
fig2, ax2 = plt.subplots(1, 5, figsize=(16,2.7))
i, j, plotfig1 = 0, 0, True
for categorical_attribute in fingerprinted_data.select_dtypes(include='object').columns:
    counts = fingerprinted_data[categorical_attribute][primary_key].value_counts()
    if plotfig1:
        chart = sns.barplot(counts.index, counts.values, alpha=.9, palette="Set3", ax=ax1[i][j])
        chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
        if j < 3: 
            j += 1
        else: 
            i += 1; j = 0
        if i == 2: 
            plotfig1 = False
            i, j = 0, 0 
    else:
        chart = sns.barplot(counts.index, counts.values, alpha=.9, palette="Set3", ax=ax2[i])
        chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
        i += 1 
fig1.tight_layout()

# %% [markdown]
# And the original distribution looked like this:

# %%
original_data, primary_key = import_dataset("german_credit")

sns.set(style="ticks")
fig1, ax1 = plt.subplots(2, 4, figsize=(12.5,6))
fig2, ax2 = plt.subplots(1, 5, figsize=(16,2.7))
i, j, plotfig1 = 0, 0, True
for categorical_attribute in original_data.select_dtypes(include='object').columns:
    counts = original_data[categorical_attribute][primary_key].value_counts()
    if plotfig1:
        chart = sns.barplot(counts.index, counts.values, alpha=.9, palette="Set3", ax=ax1[i][j])
        chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
        if j < 3: 
            j += 1
        else: 
            i += 1; j = 0
        if i == 2: 
            plotfig1 = False
            i, j = 0, 0 
    else:
        chart = sns.barplot(counts.index, counts.values, alpha=.9, palette="Set3", ax=ax2[i])
        chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
        i += 1 
fig1.tight_layout()
# Out:
# Dataset: datasets/german_credit.csv
