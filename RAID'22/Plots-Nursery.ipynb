# %%
import os
os.chdir("C:\\Users\\tsarcevic\\PycharmProjects\\fingerprinting-toolbox")

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import pickle
from datasets import GermanCredit

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

# %% [markdown]
# ## Vertical

# %%
# load robustness results
with open('parameter_guidelines/Nursery/evaluation/robustness_vertical_universal_c95_e30.pickle', 'rb') as infile:
    robustness_vertical_8attr = pickle.load(infile)

# %%
# load utility results
with open('parameter_guidelines/evaluation/nursery/utility_ml_baseline.pickle', 'rb') as infile:
    utility_ml_baseline = pickle.load(infile)
with open('parameter_guidelines/evaluation/nursery/utility_fp_gb_fpattr8_e30.pickle', 'rb') as infile:
    utility_fp_gb_fpattr8_e80 = pickle.load(infile)
with open('parameter_guidelines/evaluation/nursery/utility_fp_lr_fpattr8_e30.pickle', 'rb') as infile:
    utility_fp_lr_fpattr8_e80 = pickle.load(infile)
with open('parameter_guidelines/evaluation/nursery/utility_fp_mlp_fpattr8_e30.pickle', 'rb') as infile:
    utility_fp_mlp_fpattr8_e80 = pickle.load(infile)
with open('parameter_guidelines/evaluation/nursery/utility_fp_knn_fpattr8_e30.pickle', 'rb') as infile:
    utility_fp_knn_fpattr8_e80 = pickle.load(infile)
with open('parameter_guidelines/evaluation/nursery/utility_fp_svm_fpattr8_e30.pickle', 'rb') as infile:
    utility_fp_svm_fpattr8_e80 = pickle.load(infile)
with open('parameter_guidelines/evaluation/nursery/utility_fp_rf_fpattr8_e30.pickle', 'rb') as infile:
    utility_fp_rf_fpattr8_e80 = pickle.load(infile)

# %%
# load attack utility loss resutls
with open('parameter_guidelines/Nursery/evaluation/rel_vertical_attack_utility_loss_gb_fpattr8.pickle', 'rb') as infile:
    attack_utility_loss_fp_gb = pickle.load(infile)
with open('parameter_guidelines/Nursery/evaluation/rel_vertical_attack_utility_loss_lr_fpattr8.pickle', 'rb') as infile:
    attack_utility_loss_fp_lr = pickle.load(infile)
with open('parameter_guidelines/Nursery/evaluation/rel_vertical_attack_utility_loss_knn_fpattr8.pickle', 'rb') as infile:
    attack_utility_loss_fp_knn = pickle.load(infile)
with open('parameter_guidelines/Nursery/evaluation/rel_vertical_attack_utility_loss_svm_fpattr8.pickle', 'rb') as infile:
    attack_utility_loss_fp_svm = pickle.load(infile)
with open('parameter_guidelines/Nursery/evaluation/rel_vertical_attack_utility_loss_rf_fpattr8.pickle', 'rb') as infile:
    attack_utility_loss_fp_rf = pickle.load(infile)
with open('parameter_guidelines/Nursery/evaluation/rel_vertical_attack_utility_loss_mlp_fpattr8.pickle', 'rb') as infile:
    attack_utility_loss_fp_mlp = pickle.load(infile)

# %%
# prep for plotting
robustness_vertical_x = 1.0 / np.array(list(robustness_vertical_8attr.keys())) # percentage of marked rows

robustness_vertical_8attr_y = robustness_vertical_8attr.values()

# %%
# prep for plotting

#utility_fp_gb_avg = dict()
#for gamma in utility_fp_gb:
#    utility_fp_gb_avg[gamma] = np.mean([np.mean(experiment) for experiment in utility_fp_gb[gamma]])
#utility_fp_gb_avg_y = utility_fp_gb_avg.values() 


# gb
utility_fp_gb_fpattr8_e80_avg = dict()
for gamma in utility_fp_gb_fpattr8_e80:
    utility_fp_gb_fpattr8_e80_avg[gamma] = np.mean([np.mean(experiment) for experiment in utility_fp_gb_fpattr8_e80[gamma]])
utility_fp_gb_fpattr8_e80_avg_y = utility_fp_gb_fpattr8_e80_avg.values()
# knn
utility_fp_knn_fpattr8_e80_avg = dict()
for gamma in utility_fp_knn_fpattr8_e80:
    utility_fp_knn_fpattr8_e80_avg[gamma] = np.mean([np.mean(experiment) for experiment in utility_fp_knn_fpattr8_e80[gamma]])
utility_fp_knn_fpattr8_e80_avg_y = utility_fp_knn_fpattr8_e80_avg.values()
# mlp
utility_fp_mlp_fpattr8_e80_avg = dict()
for gamma in utility_fp_mlp_fpattr8_e80:
    utility_fp_mlp_fpattr8_e80_avg[gamma] = np.mean([np.mean(experiment) for experiment in utility_fp_mlp_fpattr8_e80[gamma]])
utility_fp_mlp_fpattr8_e80_avg_y = utility_fp_mlp_fpattr8_e80_avg.values()
# lr
utility_fp_lr_fpattr8_e80_avg = dict()
for gamma in utility_fp_lr_fpattr8_e80:
    utility_fp_lr_fpattr8_e80_avg[gamma] = np.mean([np.mean(experiment) for experiment in utility_fp_lr_fpattr8_e80[gamma]])
utility_fp_lr_fpattr8_e80_avg_y = utility_fp_lr_fpattr8_e80_avg.values()
# svm
utility_fp_svm_fpattr8_e80_avg = dict()
for gamma in utility_fp_svm_fpattr8_e80:
    utility_fp_svm_fpattr8_e80_avg[gamma] = np.mean([np.mean(experiment) for experiment in utility_fp_svm_fpattr8_e80[gamma]])
utility_fp_svm_fpattr8_e80_avg_y = utility_fp_svm_fpattr8_e80_avg.values()
# rf
utility_fp_rf_fpattr8_e80_avg = dict()
for gamma in utility_fp_rf_fpattr8_e80:
    utility_fp_rf_fpattr8_e80_avg[gamma] = np.mean([np.mean(experiment) for experiment in utility_fp_rf_fpattr8_e80[gamma]])
utility_fp_rf_fpattr8_e80_avg_y = utility_fp_rf_fpattr8_e80_avg.values()

# %%
utility_fp_gb_fpattr8_e80_avg
# Out:
# {1: 0.7405195473251028,
#  1.11: 0.7398842592592594,
#  1.25: 0.7300977366255145,
#  1.43: 0.7180684156378601,
#  1.67: 0.7149819958847736,
#  2: 0.7208101851851851,
#  2.5: 0.723996913580247,
#  3: 0.7207355967078188,
#  4: 0.7147968106995884,
#  5: 0.7057175925925926,
#  10: 0.6799717078189301,
#  18: 0.6590509259259262}

# %%
# prep for plotting
attack_utility_loss_fp_gb_mean = [abs(np.mean([np.mean(util) for util in attack_utility_loss_fp_gb[gamma]]))*100 for gamma in 
                                      attack_utility_loss_fp_gb]
attack_utility_loss_fp_rf_mean = [abs(np.mean([np.mean(util) for util in attack_utility_loss_fp_rf[gamma]]))*100 for gamma in 
                                      attack_utility_loss_fp_rf]
attack_utility_loss_fp_mlp_mean = [abs(np.mean([np.mean(util) for util in attack_utility_loss_fp_mlp[gamma]]))*100 for gamma in 
                                      attack_utility_loss_fp_mlp]
attack_utility_loss_fp_knn_mean = [abs(np.mean([np.mean(util) for util in attack_utility_loss_fp_knn[gamma]]))*100 for gamma in 
                                      attack_utility_loss_fp_knn]
attack_utility_loss_fp_lr_mean = [abs(np.mean([np.mean(util) for util in attack_utility_loss_fp_lr[gamma]]))*100 for gamma in 
                                      attack_utility_loss_fp_lr]
attack_utility_loss_fp_svm_mean = [abs(np.mean([np.mean(util) for util in attack_utility_loss_fp_svm[gamma]]))*100 for gamma in 
                                      attack_utility_loss_fp_svm]
utility_loss_x = [1, 0.5, 0.3333, 0.25, 0.2, 0.1667, 0.14285714, 0.125, 0.11111111, 0.1, 0.08333333, 0.06666667, 0.05555556]

# %%
# load targeted attack utility loss results 
with open('parameter_guidelines/Nursery/evaluation/rel_targeted_vertical_attack_utility_loss_gb_sk0.pkl', 'rb') as infile:
    targeted_attack_utility_loss_attr8 = pickle.load(infile)

# %%
# prep for plotting 
targeted_attack_utility_loss_attr8_mean=[]
for gamma in targeted_attack_utility_loss_attr8:
    targeted_attack_utility_loss_attr8_mean.append(100*np.mean(targeted_attack_utility_loss_attr8[gamma]))

# %%
#plt.plot(horizontal_x, utility_line_2, color='#ffe3e3', label='attacker loses >1% of acc')
#plt.fill_between(horizontal_x, [0.81 for i in horizontal_x], utility_line_2, color='#ffe3e3')

#plt.plot(horizontal_x, utility_line, color='#ffabab', label='attacker loses >2% of acc')#
#plt.fill_between(horizontal_x, [0.81 for i in horizontal_x], utility_line, color='#ffabab')
fig, axs = plt.subplots(1,3, figsize=(20,4))

# ROBUSTNESS PLOT

axs[0].plot(robustness_vertical_x, list(robustness_vertical_8attr_y), label='all atrributes marked', color=colors[0])  # 8 values are <2% and then more

axs[0].set_xlabel('% marks')
axs[0].set_ylabel('robustness')
axs[0].legend()
axs[0].grid()
#axs[0].set_title('Vertical subset attack')

# UTILITY PLOT
#axs[1].plot(robustness_vertical_x, utility_fp_gb_avg_y, label='20 attributes marked')
#axs[1].plot(robustness_vertical_x, utility_fp_gb_e80_avg_y, label='20 attributes marked')
#axs[1].plot(robustness_vertical_x, utility_fp_gb_fpattr16_e80_avg_y, label='16 attributes marked') 
#axs[1].plot(robustness_vertical_x, utility_fp_gb_fpattr12_e80_avg_y, label='12 attributes marked')
#axs[1].plot(robustness_vertical_x, utility_fp_gb_fpattr8_e80_avg_y, label='8 attributes marked')
#axs[1].plot(robustness_vertical_x, utility_fp_gb_fpattr4_e80_avg_y, label='4 attributes marked')



#axs[1].plot(robustness_vertical_x, gb_baseline_y, label='GB baseline')

#axs[1].set_xlabel('% marks')
#axs[1].set_ylabel('accuracy')
#axs[1].legend()
#axs[1].grid()
#axs[1].set_title('Utility loss due to the fingerprint')

# ATTACK UTILITY LOSS PLOT
axs[1].plot(robustness_vertical_x, attack_utility_loss_fp_gb_mean, label='Gradient Boosting')
axs[1].plot(robustness_vertical_x, attack_utility_loss_fp_knn_mean, label='k-Nearest Neighbours')
axs[1].plot(robustness_vertical_x, attack_utility_loss_fp_lr_mean, label='Logistic Regression')
axs[1].plot(robustness_vertical_x, attack_utility_loss_fp_svm_mean, label='SVM')
axs[1].plot(robustness_vertical_x, attack_utility_loss_fp_rf_mean, label='Random Forest')
axs[1].plot(robustness_vertical_x, attack_utility_loss_fp_mlp_mean, label='MLP')


axs[1].set_yticks([0,5,10,15,20,25,30,35,40,45,50,55])
axs[1].set_yticklabels(['0%','','10%','','20%','','30%','','40%','','50%',''])
axs[1].set_xlabel('% marks')
axs[1].set_ylabel('accuracy loss rel to initial accuracy')
axs[1].legend()
axs[1].grid()
#axs[1].set_title('Utility loss after applying the weakest successful attack')

axs[2].get_shared_y_axes().join(axs[1], axs[2])
axs[2].plot(robustness_vertical_x, targeted_attack_utility_loss_attr8_mean, label='Gradient Boosting')


axs[2].set_yticks([0,5,10,15,20,25,30,35,40,45,50,55])
axs[2].set_yticklabels(['0%','','10%','','20%','','30%','','40%','','50%',''])
axs[2].set_xlabel('% marks')
axs[2].grid()
axs[2].legend()
#axs[2].set_title('Targeted attack')

# %% [markdown]
# ## Horizontal

# %%
# load robustness results
with open('parameter_guidelines/Nursery/evaluation/robustness_horizontal_universal_c95_e30.pickle', 'rb') as infile:
    robustness_horizontal_8attr = pickle.load(infile)

# %%
# load attack utility loss resutls
with open('parameter_guidelines/Nursery/evaluation/rel_horizontal_attack_utility_loss_gb_fpattr8.pickle', 'rb') as infile:
    attack_utility_loss_fp_gb = pickle.load(infile)
with open('parameter_guidelines/Nursery/evaluation/rel_horizontal_attack_utility_loss_lr_fpattr8.pickle', 'rb') as infile:
    attack_utility_loss_fp_lr = pickle.load(infile)
with open('parameter_guidelines/Nursery/evaluation/rel_horizontal_attack_utility_loss_knn_fpattr8.pickle', 'rb') as infile:
    attack_utility_loss_fp_knn = pickle.load(infile)
with open('parameter_guidelines/Nursery/evaluation/rel_horizontal_attack_utility_loss_svm_fpattr8.pickle', 'rb') as infile:
    attack_utility_loss_fp_svm = pickle.load(infile)
with open('parameter_guidelines/Nursery/evaluation/rel_horizontal_attack_utility_loss_rf_fpattr8.pickle', 'rb') as infile:
    attack_utility_loss_fp_rf = pickle.load(infile)
with open('parameter_guidelines/Nursery/evaluation/rel_horizontal_attack_utility_loss_mlp_fpattr8.pickle', 'rb') as infile:
    attack_utility_loss_fp_mlp = pickle.load(infile)

# %%
# undersampling results
with open('parameter_guidelines/Nursery/evaluation/rel_undersampling_attack_utilities_gb_fpattr8_e10.pkl', 'rb') as infile:
    rel_undersampling_attack_utility_gb_fpattr8 = pickle.load(infile)
with open('parameter_guidelines/Nursery/evaluation/rel_undersampling_attack_utilities_rf_fpattr8_e10.pkl', 'rb') as infile:
    rel_undersampling_attack_utility_rf_fpattr8 = pickle.load(infile)
with open('parameter_guidelines/Nursery/evaluation/rel_undersampling_attack_utilities_lr_fpattr8_e10.pkl', 'rb') as infile:
    rel_undersampling_attack_utility_lr_fpattr8 = pickle.load(infile)
with open('parameter_guidelines/Nursery/evaluation/rel_undersampling_attack_utilities_knn_fpattr8_e10.pkl', 'rb') as infile:
    rel_undersampling_attack_utility_knn_fpattr8 = pickle.load(infile)
with open('parameter_guidelines/Nursery/evaluation/rel_undersampling_attack_utilities_svm_fpattr8_e10.pkl', 'rb') as infile:
    rel_undersampling_attack_utility_svm_fpattr8 = pickle.load(infile)
with open('parameter_guidelines/Nursery/evaluation/rel_undersampling_attack_utilities_mlp_fpattr8_e10.pkl', 'rb') as infile:
    rel_undersampling_attack_utility_mlp_fpattr8 = pickle.load(infile)

# %%
rel_undersampling_attack_utility_rf_fpattr8[18]
# Out:
# [array([-0.29564258, -0.37529551, -0.2002007 , -0.31671403, -0.35327887]),
#  array([-0.31747788, -0.33520179, -0.23945094, -0.32682199, -0.36156304]),
#  array([-0.31078815, -0.28781284, -0.20452261, -0.33056755, -0.38763774]),
#  array([-0.30480984, -0.33900227, -0.18968969, -0.29773508, -0.3435366 ]),
#  array([-0.30955056, -0.22222222, -0.21392276, -0.32574531, -0.34142146]),
#  array([-0.3118701 , -0.2576    , -0.22076613, -0.33244157, -0.36342526]),
#  array([-0.27620087, -0.27093596, -0.17655786, -0.31675637, -0.34174059]),
#  array([-0.30277306, -0.2345679 , -0.17888999, -0.286089  , -0.34985237]),
#  array([-0.24325782, -0.37703963, -0.2012012 , -0.288453  , -0.36768023]),
#  array([-0.31590656, -0.42061114, -0.18123138, -0.33915858, -0.39063975])]

# %%
# prep for plotting
robustness_horizontal_x = 1.0 / np.array(list(robustness_horizontal_8attr.keys())) # percentage of marked rows

robustness_horizontal_8attr_y = robustness_horizontal_8attr.values()

# %%
# prep for plotting
attack_utility_loss_fp_gb_mean = [abs(np.mean([np.mean(util) for util in attack_utility_loss_fp_gb[gamma]]))*100 for gamma in 
                                      attack_utility_loss_fp_gb]
attack_utility_loss_fp_rf_mean = [abs(np.mean([np.mean(util) for util in attack_utility_loss_fp_rf[gamma]]))*100 for gamma in 
                                      attack_utility_loss_fp_rf]
attack_utility_loss_fp_mlp_mean = [abs(np.mean([np.mean(util) for util in attack_utility_loss_fp_mlp[gamma]]))*100 for gamma in 
                                      attack_utility_loss_fp_mlp]
attack_utility_loss_fp_knn_mean = [abs(np.mean([np.mean(util) for util in attack_utility_loss_fp_knn[gamma]]))*100 for gamma in 
                                      attack_utility_loss_fp_knn]
attack_utility_loss_fp_lr_mean = [abs(np.mean([np.mean(util) for util in attack_utility_loss_fp_lr[gamma]]))*100 for gamma in 
                                      attack_utility_loss_fp_lr]
attack_utility_loss_fp_svm_mean = [abs(np.mean([np.mean(util) for util in attack_utility_loss_fp_svm[gamma]]))*100 for gamma in 
                                      attack_utility_loss_fp_svm]
utility_loss_x = [1, 0.5, 0.3333, 0.25, 0.2, 0.1667, 0.14285714, 0.125, 0.11111111, 0.1, 0.08333333, 0.06666667, 0.05555556]

# %%
# prep for plotting
rel_undersampling_attack_utility_gb_fpattr8_mean = [np.mean([np.mean(util[[0,2,3]]) 
                                                           for util in rel_undersampling_attack_utility_gb_fpattr8[gamma]])*100 
                                                  for gamma in rel_undersampling_attack_utility_gb_fpattr8]
rel_undersampling_attack_utility_rf_fpattr8_mean = [np.mean([np.mean(util[2]) 
                                                           for util in rel_undersampling_attack_utility_rf_fpattr8[gamma]])*100 
                                                  for gamma in rel_undersampling_attack_utility_rf_fpattr8]
rel_undersampling_attack_utility_lr_fpattr8_mean = [np.mean([np.mean(util) 
                                                           for util in rel_undersampling_attack_utility_lr_fpattr8[gamma]])*100 
                                                  for gamma in rel_undersampling_attack_utility_lr_fpattr8]
rel_undersampling_attack_utility_knn_fpattr8_mean = [np.mean([np.mean(util[[0,2,3]]) 
                                                           for util in rel_undersampling_attack_utility_knn_fpattr8[gamma]])*100 
                                                  for gamma in rel_undersampling_attack_utility_knn_fpattr8]
rel_undersampling_attack_utility_svm_fpattr8_mean = [np.mean([np.mean(util) 
                                                           for util in rel_undersampling_attack_utility_svm_fpattr8[gamma]])*100 
                                                  for gamma in rel_undersampling_attack_utility_svm_fpattr8]
rel_undersampling_attack_utility_mlp_fpattr8_mean = [np.mean([np.mean(util) 
                                                           for util in rel_undersampling_attack_utility_mlp_fpattr8[gamma]])*100 
                                                  for gamma in rel_undersampling_attack_utility_mlp_fpattr8]

# %%
#plt.plot(horizontal_x, utility_line_2, color='#ffe3e3', label='attacker loses >1% of acc')
#plt.fill_between(horizontal_x, [0.81 for i in horizontal_x], utility_line_2, color='#ffe3e3')

#plt.plot(horizontal_x, utility_line, color='#ffabab', label='attacker loses >2% of acc')#
#plt.fill_between(horizontal_x, [0.81 for i in horizontal_x], utility_line, color='#ffabab')
fig, axs = plt.subplots(1,3, figsize=(20,4))

# ROBUSTNESS PLOT

axs[0].plot(robustness_horizontal_x, list(robustness_horizontal_8attr_y), label='all atrributes marked')  # 8 values are <2% and then more

axs[0].set_xlabel('% marks')
axs[0].set_ylabel('robustness')
axs[0].legend()
axs[0].grid()
#axs[0].set_title('Horizontal subset attack')

# UTILITY PLOT
#axs[1].plot(robustness_horizontal_x, utility_fp_gb_avg_y, label='20 attributes marked')
#axs[1].plot(robustness_horizontal_x, utility_fp_gb_e80_avg_y, label='20 attributes marked')
#axs[1].plot(robustness_horizontal_x, utility_fp_gb_fpattr16_e80_avg_y, label='16 attributes marked') 
#axs[1].plot(robustness_horizontal_x, utility_fp_gb_fpattr12_e80_avg_y, label='12 attributes marked')
#axs[1].plot(robustness_horizontal_x, utility_fp_gb_fpattr8_e80_avg_y, label='8 attributes marked')
#axs[1].plot(robustness_horizontal_x, utility_fp_gb_fpattr4_e80_avg_y, label='4 attributes marked')



#axs[1].plot(robustness_horizontal_x, gb_baseline_y, label='GB baseline')

#axs[1].set_xlabel('% marks')
#axs[1].set_ylabel('accuracy')
#axs[1].legend()
#axs[1].grid()
#axs[1].set_title('Utility loss due to the fingerprint')

# ATTACK UTILITY LOSS PLOT
axs[1].plot(robustness_horizontal_x, attack_utility_loss_fp_gb_mean, label='Gradient Boosting')
axs[1].plot(robustness_horizontal_x, attack_utility_loss_fp_knn_mean, label='k-Nearest Neighbours')
axs[1].plot(robustness_horizontal_x, attack_utility_loss_fp_lr_mean, label='Logistic Regression')
axs[1].plot(robustness_horizontal_x, attack_utility_loss_fp_svm_mean, label='SVM')
axs[1].plot(robustness_horizontal_x, attack_utility_loss_fp_rf_mean, label='Random Forest')
axs[1].plot(robustness_horizontal_x, attack_utility_loss_fp_mlp_mean, label='MLP')


axs[1].set_yticks([-30,-25,-20,-15,-10,-5,0,5,10,15,20])
axs[1].set_yticklabels(['-30%','','-20%','','-10%','','0%','','10%','','20%'])
axs[1].set_xlabel('% marks')
axs[1].set_ylabel('accuracy loss rel to initial accuracy')
axs[1].legend()
axs[1].grid()
#axs[1].set_title('Utility loss after applying the weakest successful attack')

axs[2].get_shared_y_axes().join(axs[1], axs[2])


axs[2].set_yticks([-30,-25,-20,-15,-10,-5,0,5,10,15,20])
axs[2].set_yticklabels(['-30%','','-20%','','-10%','','0%','','10%','','20%'])
axs[2].set_xlabel('% marks')

axs[2].plot(robustness_horizontal_x, rel_undersampling_attack_utility_gb_fpattr8_mean, label='Gradient Boosting')
axs[2].plot(robustness_horizontal_x, rel_undersampling_attack_utility_knn_fpattr8_mean, label='k-Nearest Neighbours')
axs[2].plot(robustness_horizontal_x, rel_undersampling_attack_utility_lr_fpattr8_mean, label='Logistic Regression')
axs[2].plot(robustness_horizontal_x, rel_undersampling_attack_utility_svm_fpattr8_mean, label='SVM')
axs[2].plot(robustness_horizontal_x, rel_undersampling_attack_utility_rf_fpattr8_mean, label='Random Forest')
axs[2].plot(robustness_horizontal_x, rel_undersampling_attack_utility_mlp_fpattr8_mean, label='MLP')

axs[2].legend()
axs[2].grid()
#axs[2].set_title('Utility loss after undersampling method')
